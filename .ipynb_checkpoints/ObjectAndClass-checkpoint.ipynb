# %%
class Myclass:
    x=5
p1=Myclass()
print(p1.x)
# Out:
# 5

# %%
del p1

# %%
p1=Myclass()
p2=Myclass()
p3=Myclass()

print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
p1=Person("Aftab",20)
print(p1.name)
print(p1.age)
# Out:
# Aftab
# 20

# %%
class Person:
    pass
p1=Person()
p1.name="Aftab"
p1.age=20
print(p1.name)
print(p1.age)
# Out:
# Aftab
# 20

# %%
class Person:
    def __init__(self,name, age=18):
        self.name=name
        self.age=age
        
p1=Person("Aftab")
p2=Person("Ahmed",25)

print(p1.name,p1.age)
print(p2.name, p2.age)
